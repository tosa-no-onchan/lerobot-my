# %%
import os
import sys
from pathlib import Path

#export PYTHONPATH=$PYTHONPATH:/home/nishi/local/git-download/lerobot/src
# パスを通す（お使いの環境に合わせて絶対パスに書き換えてください）
# git clone をした、パスを使ってください。
lerobot_path = "/home/your-id/local/git-download/lerobot"
sys.path.append(os.path.join(lerobot_path, "src"))

# %%
from lerobot.datasets.lerobot_dataset import LeRobotDataset
# データセットを直接読み込む
DATASET_ID = "lerobot/aloha_sim_transfer_cube_human"
dataset = LeRobotDataset(DATASET_ID)
# 1. データセットに含まれる全タスクの一覧（メタデータ）を表示
print("登録されているタスク一覧:")
print(dataset.meta.tasks)

# %%
# 2. 最初のエピソードのタスク記述を確認
# データセットのフレーム（例: インデックス0）から直接取得可能
frame = dataset[0]
if "task" in frame:
    print(f"現在のフレームのタスク指示文: {frame['task']}")

# %%
print('frame:',frame)
